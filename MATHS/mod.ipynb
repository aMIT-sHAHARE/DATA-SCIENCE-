# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("./titanic_clean.csv")
dataset.head(3)
# Out:
#    PassengerId  Survived  Pclass         Name     Sex   Age  SibSp  Parch  \
# 0            1         0       2  Passenger_1  female  55.3      0      1
# 1            2         1       3  Passenger_2  female  35.5      2      1
# 2            3         0       1  Passenger_3    male  43.9      3      0
#
#      Ticket   Fare Cabin Embarked
# 0  TKT10000  35.31   NaN        S
# 1  TKT10001  10.41   NaN        S
# 2  TKT10002  41.53   NaN        C

# %% [markdown]
# ## Mode

# %%
mo=dataset["Fare"].mode()[0]

# %%
# dataset["Fare"].value_counts()

# %% [markdown]
# ## Median

# %%
dataset["Fare"].median()
# Out:
# np.float64(24.19)

# %%
md= np.median(dataset["Fare"])

# %% [markdown]
# ## Mean

# %%
dataset["Fare"].mean()
# Out:
# np.float64(30.173052749719414)

# %%
mn=np.mean(dataset["Fare"])

# %%
sns.histplot(x="Fare",data=dataset,bins=[i for i in range(0,81,10)])
plt.plot([mn for i in range(0,300)],[i for i in range(0,300)],c="red")
plt.plot([md for i in range(0,300)],[i for i in range(0,300)],c="blue")
plt.plot([mo for i in range(0,300)],[i for i in range(0,300)],c="yellow")
