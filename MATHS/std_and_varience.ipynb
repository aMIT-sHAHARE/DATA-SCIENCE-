# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("./titanic_clean.csv")
dataset.head(4)
# Out:
#    PassengerId  Survived  Pclass         Name     Sex   Age  SibSp  Parch  \
# 0            1         0       2  Passenger_1  female  55.3      0      1
# 1            2         1       3  Passenger_2  female  35.5      2      1
# 2            3         0       1  Passenger_3    male  43.9      3      0
# 3            4         0       2  Passenger_4    male  62.2      1      3
#
#      Ticket   Fare Cabin Embarked
# 0  TKT10000  35.31   NaN        S
# 1  TKT10001  10.41   NaN        S
# 2  TKT10002  41.53   NaN        C
# 3  TKT10003   4.28   NaN        S

# %%
dataset["Age"].std()
# Out:
# np.float64(13.956221639396178)

# %%
dataset["Age"].var()
# Out:
# np.float64(194.77612244795014)

# %%
sns.histplot(x="Age",data=dataset)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.405163    2.347924   28.814254    2.447811
# std     257.353842    0.491199    0.804582   13.956222    1.711929
# min       1.000000    0.000000    1.000000    0.400000    0.000000
# 25%     223.500000    0.000000    2.000000   19.250000    1.000000
# 50%     446.000000    0.000000    3.000000   28.700000    2.000000
# 75%     668.500000    1.000000    3.000000   38.200000    4.000000
# max     891.000000    1.000000    3.000000   68.800000    5.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     1.983165   30.173053
# std      1.426376   22.303235
# min      0.000000    0.820000
# 25%      1.000000   14.180000
# 50%      2.000000   24.190000
# 75%      3.000000   39.955000
# max      4.000000  153.000000
